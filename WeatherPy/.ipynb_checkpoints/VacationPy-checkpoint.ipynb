# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("output_data/cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df.head()
# Out:
#    City_ID                      City      Lat       Lng  Max Temp  Humidity  \
# 0        0                   iqaluit  63.7506  -68.5145     38.93        75
# 1        1                whitehorse  60.7161 -135.0538     42.10        93
# 2        2  petropavlovsk-kamchatsky  53.0452  158.6483     48.78        73
# 3        3                    newman  37.3138 -121.0208     71.58        42
# 4        4       phan rang-thap cham  11.5667  108.9833     88.18        71
#
#    Cloudiness  Wind Speed Country        Date
# 0          75       13.80      CA  1696574798
# 1          40       27.63      CA  1696574799
# 2          75       11.18      RU  1696574800
# 3           0        3.69      US  1696574801
# 4          88       10.25      VN  1696574802

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

city_data_df = city_data_df.sort_values("City",ascending=False)

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
                                        "Lng",
                                        "Lat",
                                        geo = True,
                                        tiles = "OSM",
                                        frame_width = 800,
                                        frame_height = 600,
                                        size = "Humidity",
                                        scale = 0.7, 
                                        color = "City",
                                        title = "City Weather Map"
   
)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
cleand_city_data = city_data_df[(city_data_df["Wind Speed"] <= 15) & (city_data_df["Cloudiness"] <= 100) & (city_data_df["Max Temp"] <= 100) & (city_data_df["Max Temp"] >= 19) & (city_data_df["Country"] == "AU")]

# Drop any rows with null values
cleand_city_data.dropna() 
# Display sample data
cleand_city_data.head(10)
# Out:
#      City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 391      391          yeppoon -23.1333  150.7333     83.98        65
# 18        18          wynyard -41.0000  145.7167     55.98        38
# 456      456        ulladulla -35.3500  150.4667     59.77        54
# 74        74        swan hill -35.3378  143.5544     63.25        38
# 347      347    south hedland -20.4089  118.5983     98.53         9
# 565      565  sanctuary point -35.1114  150.6290     61.75        54
# 82        82     port lincoln -34.7333  135.8667     58.78        56
# 156      156      new norfolk -42.7826  147.0587     53.92        57
# 533      533       nelson bay -32.7167  152.1500     65.08        75
# 563      563       naracoorte -36.9579  140.7383     60.33        41
#
#      Cloudiness  Wind Speed Country        Date
# 391           7       10.98      AU  1696575214
# 18           12        9.35      AU  1696574816
# 456          55       14.88      AU  1696575283
# 74            6       11.79      AU  1696574693
# 347           1       13.80      AU  1696575165
# 565          82       14.43      AU  1696575399
# 82           99       11.32      AU  1696574883
# 156          99        6.15      AU  1696574961
# 533          94       10.00      AU  1696575365
# 563          26       11.83      AU  1696575397

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = cleand_city_data.loc[:, ["City", "Country", "Lat", "Lng","Humidity"]]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head(10)
# Out:
#                 City Country      Lat       Lng  Humidity Hotel Name
# 391          yeppoon      AU -23.1333  150.7333        65
# 18           wynyard      AU -41.0000  145.7167        38
# 456        ulladulla      AU -35.3500  150.4667        54
# 74         swan hill      AU -35.3378  143.5544        38
# 347    south hedland      AU -20.4089  118.5983         9
# 565  sanctuary point      AU -35.1114  150.6290        54
# 82      port lincoln      AU -34.7333  135.8667        56
# 156      new norfolk      AU -42.7826  147.0587        57
# 533       nelson bay      AU -32.7167  152.1500        75
# 563       naracoorte      AU -36.9579  140.7383        41

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000 
params = {
     "categories":"accommodation.hotel",
     "apiKey": geoapify_key,
     "limit":20
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame    
    latitude = hotel_df.loc[index,"Lat"]
    longitude = hotel_df.loc[index,"Lng"]   
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] =  f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address =  requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# yeppoon - nearest hotel: Blossom's on Seaspray
# wynyard - nearest hotel: Wynyard Hotel
# ulladulla - nearest hotel: Hotel Marlin
# swan hill - nearest hotel: Murray Downs Golf Resort
# south hedland - nearest hotel: Port Haven
# sanctuary point - nearest hotel: Dungowan Accommodation
# port lincoln - nearest hotel: Boston Hotel
# new norfolk - nearest hotel: Woodbridge on the Derwent
# nelson bay - nearest hotel: No hotel found
# naracoorte - nearest hotel: Kincraig Hotel /Smith & Jones Cafe
# mount isa - nearest hotel: Ibis Styles
# mount gambier - nearest hotel: The Old Mount Gambier Gaol
# margaret river - nearest hotel: Margaret River Hotel
# kununurra - nearest hotel: Kununurra Country Club Resort
# karratha - nearest hotel: Karratha International Hotel
# howard springs - nearest hotel: No hotel found
# geraldton - nearest hotel: Ocean Centre Hotel
# cooma - nearest hotel: Royal Hotel
# codrington - nearest hotel: No hotel found
# broken hill - nearest hotel: Ibis Styles
# blackmans bay - nearest hotel: Villa Howden
# andergrove - nearest hotel: No hotel found
#                 City Country      Lat       Lng  Humidity  \
# 391          yeppoon      AU -23.1333  150.7333        65
# 18           wynyard      AU -41.0000  145.7167        38
# 456        ulladulla      AU -35.3500  150.4667        54
# 74         swan hill      AU -35.3378  143.5544        38
# 347    south hedland      AU -20.4089  118.5983         9
# 565  sanctuary point      AU -35.1114  150.6290        54
# 82      port lincoln      AU -34.7333  135.8667        56
# 156      new norfolk      AU -42.7826  147.0587        57
# 533       nelson bay      AU -32.7167  152.1500        75
# 563       naracoorte      AU -36.9579  140.7383        41
# 144        mount isa      AU -20.7333  139.5000        11
# 329    mount gambier      AU -37.8333  140.7667        60
# 211   margaret river      AU -33.9500  115.0667        55
# 133        kununurra      AU -15.7667  128.7333        20
# 134         karratha      AU -20.7377  116.8463        18
# 140   howard springs      AU -12.4970  131.0470        44
# 568        geraldton      AU -28.7667  114.6000        23
# 542            cooma      AU -36.2333  149.1333        45
# 129       codrington      AU -38.2667  141.9667        59
# 320      broken hill      AU -31.9500  141.4333        46
# 95     blackmans bay      AU -43.0167  147.3167        58
# 481       andergrove      AU -21.0833  149.1833        77
#
#                              Hotel Name
# 391               Blossom's on Seaspray
# 18                        Wynyard Hotel
# 456                        Hotel Marlin
# 74             Murray Downs Golf Resort
# 347                          Port Haven
# 565              Dungowan Accommodation
# 82                         Boston Hotel
# 156           Woodbridge on the Derwent
# 533                      No hotel found
# 563  Kincraig Hotel /Smith & Jones Cafe
# 144                         Ibis Styles
# 329          The Old Mount Gambier Gaol
# 211                Margaret River Hotel
# 133       Kununurra Country Club Resort
# 134        Karratha International Hotel
# 140                      No hotel found
# 568                  Ocean Centre Hotel
# 542                         Royal Hotel
# 129                      No hotel found
# 320                         Ibis Styles
# 95                         Villa Howden
# 481                      No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

hotel_df = hotel_df.sort_values("City",ascending=False)

# Configure the map plot
map_plot_2= hotel_df.hvplot.points( "Lng",
                                    "Lat",                   
                                    geo = True,
                                    tiles = "EsriImagery",
                                    hover_cols=['Hotel Name', 'Country'],
                                    frame_width = 800,
                                    frame_height = 600,
                                    size = "Humidity",
                                    cmap='RdYlGn',
                                    scale = 0.7, 
                                    color = "City", 
                                    title='Hotel Map'
                                  )

# Display the map
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
