# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 592

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
unit = "imperial"
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=" + unit
    response = requests.get(city_url)
        
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grytviken
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | kuala terengganu
# Processing Record 4 of Set 1 | port mathurin
# Processing Record 5 of Set 1 | nizhnesortymskiy
# Processing Record 6 of Set 1 | salinopolis
# Processing Record 7 of Set 1 | san antonio de pale
# Processing Record 8 of Set 1 | longyearbyen
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | enewetak
# Processing Record 11 of Set 1 | prince rupert
# Processing Record 12 of Set 1 | ilulissat
# Processing Record 13 of Set 1 | bethel
# Processing Record 14 of Set 1 | adamstown
# Processing Record 15 of Set 1 | khandyga
# Processing Record 16 of Set 1 | fale old settlement
# Processing Record 17 of Set 1 | cova figueira
# Processing Record 18 of Set 1 | alofi
# Processing Record 19 of Set 1 | sterling
# Processing Record 20 of Set 1 | praia da vitoria
# Processing Record 21 of Set 1 | myitkyina
# Processing Record 22 of Set 1 | puerto natales
# Processing Record 23 of Set 1 | mitchell
# Processing Record 24 of Set 1 | ust-nera
# Processing Record 25 of Set 1 | aioun
# Processing Record 26 of Set 1 | labuan
# Processing Record 27 of Set 1 | ribeira grande
# Processing Record 28 of Set 1 | misratah
# Processing Record 29 of Set 1 | lospalos
# Processing Record 30 of Set 1 | port-aux-francais
# Processing Record 31 of Set 1 | konarka
# Processing Record 32 of Set 1 | mount gambier
# Processing Record 33 of Set 1 | yagry
# City not found. Skipping...
# Processing Record 34 of Set 1 | waitangi
# Processing Record 35 of Set 1 | hastings
# Processing Record 36 of Set 1 | kourou
# Processing Record 37 of Set 1 | al ghayzah
# Processing Record 38 of Set 1 | viedma
# Processing Record 39 of Set 1 | tralee
# Processing Record 40 of Set 1 | alto araguaia
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | siuna
# Processing Record 43 of Set 1 | edinburgh of the seven seas
# Processing Record 44 of Set 1 | papao
# Processing Record 45 of Set 1 | mapimi
# Processing Record 46 of Set 1 | turka
# Processing Record 47 of Set 1 | ormara
# Processing Record 48 of Set 1 | queenstown
# Processing Record 49 of Set 1 | boa esperanca
# Processing Record 50 of Set 1 | hithadhoo
# Processing Record 0 of Set 2 | punta arenas
# Processing Record 1 of Set 2 | myeik
# Processing Record 2 of Set 2 | det udom
# Processing Record 3 of Set 2 | happy valley-goose bay
# Processing Record 4 of Set 2 | invercargill
# Processing Record 5 of Set 2 | al bayda'
# Processing Record 6 of Set 2 | olonkinbyen
# Processing Record 7 of Set 2 | albertina
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | el bolson
# Processing Record 10 of Set 2 | grand falls-windsor
# Processing Record 11 of Set 2 | dudinka
# Processing Record 12 of Set 2 | blackmans bay
# Processing Record 13 of Set 2 | college
# Processing Record 14 of Set 2 | quelimane
# Processing Record 15 of Set 2 | tanrake village
# City not found. Skipping...
# Processing Record 16 of Set 2 | isafjordur
# Processing Record 17 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 18 of Set 2 | albany
# Processing Record 19 of Set 2 | nar'yan-mar
# Processing Record 20 of Set 2 | vorgashor
# Processing Record 21 of Set 2 | tanaina
# Processing Record 22 of Set 2 | sosnovka
# Processing Record 23 of Set 2 | pervomayskoye
# Processing Record 24 of Set 2 | yangor
# City not found. Skipping...
# Processing Record 25 of Set 2 | zemio
# Processing Record 26 of Set 2 | corabia
# Processing Record 27 of Set 2 | hawaiian paradise park
# Processing Record 28 of Set 2 | aswan
# Processing Record 29 of Set 2 | vadso
# Processing Record 30 of Set 2 | wenling
# Processing Record 31 of Set 2 | talnakh
# Processing Record 32 of Set 2 | chernyshevskiy
# Processing Record 33 of Set 2 | edson
# Processing Record 34 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 35 of Set 2 | port macquarie
# Processing Record 36 of Set 2 | avarua
# Processing Record 37 of Set 2 | stanley
# Processing Record 38 of Set 2 | papatowai
# Processing Record 39 of Set 2 | acarau
# Processing Record 40 of Set 2 | wailua homesteads
# Processing Record 41 of Set 2 | qaqortoq
# Processing Record 42 of Set 2 | arraial do cabo
# Processing Record 43 of Set 2 | kataragama
# City not found. Skipping...
# Processing Record 44 of Set 2 | thompson
# Processing Record 45 of Set 2 
of Set 4 | petropavlovsk-kamchatsky
# Processing Record 34 of Set 4 | tolanaro
# Processing Record 35 of Set 4 | george town
# Processing Record 36 of Set 4 | xilin hot
# Processing Record 37 of Set 4 | georgetown
# Processing Record 38 of Set 4 | miyazaki
# Processing Record 39 of Set 4 | iwanai
# Processing Record 40 of Set 4 | tidjikja
# Processing Record 41 of Set 4 | sault ste. marie
# Processing Record 42 of Set 4 | vilyuchinsk
# Processing Record 43 of Set 4 | winejok
# City not found. Skipping...
# Processing Record 44 of Set 4 | dwarka
# Processing Record 45 of Set 4 | tofol
# Processing Record 46 of Set 4 | karratha
# Processing Record 47 of Set 4 | remire-montjoly
# Processing Record 48 of Set 4 | axim
# Processing Record 49 of Set 4 | le port
# Processing Record 0 of Set 5 | midvagur
# Processing Record 1 of Set 5 | caqueza
# Processing Record 2 of Set 5 | olyokminsk
# Processing Record 3 of Set 5 | santa elena de uairen
# Processing Record 4 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 5 of Set 5 | felege neway
# Processing Record 6 of Set 5 | nyagan
# Processing Record 7 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 8 of Set 5 | zeya
# Processing Record 9 of Set 5 | bam
# Processing Record 10 of Set 5 | rozdilna
# Processing Record 11 of Set 5 | la passe
# Processing Record 12 of Set 5 | oranjemund
# Processing Record 13 of Set 5 | hammerfest
# Processing Record 14 of Set 5 | port lincoln
# Processing Record 15 of Set 5 | carnarvon
# Processing Record 16 of Set 5 | bei'an
# Processing Record 17 of Set 5 | yuzhno-kurilsk
# Processing Record 18 of Set 5 | pathein
# Processing Record 19 of Set 5 | saipan
# Processing Record 20 of Set 5 | ponta delgada
# Processing Record 21 of Set 5 | kone
# Processing Record 22 of Set 5 | san juan de miraflores
# Processing Record 23 of Set 5 | chibougamau
# Processing Record 24 of Set 5 | rockport
# Processing Record 25 of Set 5 | carloforte
# Processing Record 26 of Set 5 | kokkola
# Processing Record 27 of Set 5 | west island
# Processing Record 28 of Set 5 | mach
# Processing Record 29 of Set 5 | broome
# Processing Record 30 of Set 5 | lompoc
# Processing Record 31 of Set 5 | san lawrenz
# Processing Record 32 of Set 5 | kokofata
# City not found. Skipping...
# Processing Record 33 of Set 5 | guerrero negro
# Processing Record 34 of Set 5 | puerto ayora
# Processing Record 35 of Set 5 | hola
# Processing Record 36 of Set 5 | susuman
# Processing Record 37 of Set 5 | inhambane
# Processing Record 38 of Set 5 | howard springs
# Processing Record 39 of Set 5 | novodvinsk
# Processing Record 40 of Set 5 | santana
# Processing Record 41 of Set 5 | san andres
# Processing Record 42 of Set 5 | kingston
# Processing Record 43 of Set 5 | souillac
# Processing Record 44 of Set 5 | phrae
# Processing Record 45 of Set 5 | ishigaki
# Processing Record 46 of Set 5 | lautoka
# Processing Record 47 of Set 5 | kurchatov
# Processing Record 48 of Set 5 | arecibo
# Processing Record 49 of Set 5 | mount isa
# Processing Record 0 of Set 6 | nizhniy odes
# Processing Record 1 of Set 6 | lesnoy
# Processing Record 2 of Set 6 | bougouni
# Processing Record 3 of Set 6 | touros
# Processing Record 4 of Set 6 | tombodu
# Processing Record 5 of Set 6 | la serena
# Processing Record 6 of Set 6 | lazaro cardenas
# Processing Record 7 of Set 6 | harstad
# Processing Record 8 of Set 6 | hassi messaoud
# Processing Record 9 of Set 6 | sao geraldo do araguaia
# Processing Record 10 of Set 6 | otaki
# Processing Record 11 of Set 6 | kerikeri
# Processing Record 12 of Set 6 | mar del plata
# Processing Record 13 of Set 6 | yorkton
# Processing Record 14 of Set 6 | loen
# Processing Record 15 of Set 6 | nagqu
# Processing Record 16 of Set 6 | antalaha
# Processing Record 17 of Set 6 | srivardhan
# Processing Record 18 of Set 6 | st. john's
# Processing Record 19 of Set 6 | polyarnyy
# Processing Record 20 of Set 6 | saint-philippe
# Processing Record 21 of Set 6 | jonuta
# Processing Record 22 of Set 6 | colonia
# Processing Record 23 of Set 6 | tinajo
# Processing Record 24 of Set 6 | bocanda
# Processing Record 25 of Set 6 | cambebba
# Processing Record 26 of Set 6 | dawson creek
# Processing Record 27 of Set 6 | urengoy
# Processing Record 28 of Set 6 | grootfontein
# Processing Record 29 of Set 6 | okondja
# Processing Record 30 of Set 6 | saurimo
# Processing Record 31 of Set 6 | borger
# Processing Record 32 of Set 6 | luderitz
# Processing Record 33 of Set 6 | brumado
# Processing Record 34 of Set 6 | quellon
# Processing Record 35 of Set 6 | maiwut
# City not found. Skipping...
# Processing Record 36 of Set 6 | panama city beach
# Processing Record 37 of Set 6 | newport
# Processing Record 38 of Set 6 | port augusta
# Processing Record 39 of Set 6 | margaret river
# Processing Record 40 of Set 6 | tyukhtet
# Processing Record 41 of Set 6 | bengkulu
# Processing Record 42 of Set 6 | nizhniy kuranakh
# Processing Record 43 of Set 6 | new norfolk
# Processing Record 44 of Set 6 | sao vicente
# Processing Record 45 of Set 6 | egilsstadir
# Processing Record 46 of Set 6 | rongelap
# Processing Record 47 of Set 6 | sao cristovao
# Processing Record 48 of Set 6 | roma
# Processing Record 49 of Set 6 | chul'man
# Processing Record 0 of Set 7 | antigonish
# Processing Record 1 of Set 7 | ippy
# Processing Record 2 of Set 7 | berezovo
# Processing Record 3 of Set 7 | sitka
# Processing Record 4 of Set 7 | taksimo
# Processing Record 5 of Set 7 | walvis bay
# Processing Record 6 of Set 7 | leninsk
# Processing Record 7 of Set 7 | kolyshley
# Processing Record 8 of Set 7 | onega
# Processing Record 9 of Set 7 | geraldton
# Processing Record 10 of Set 7 | malango
# Processing Record 11 of Set 7 | mugia
# Processing Record 12 of Set 7 | mount pearl
# Processing Record 13 of Set 7 | chilecito
# Processing Record 14 of Set 7 | bardai
# Processing Record 15 of Set 7 | rawson
# Processing Record 16 of Set 7 | tazovsky
# Processing Record 17 of Set 7 | amahai
# Processing Record 18 of Set 7 | hermanus
# Processing Record 19 of Set 7 | hotan
# Processing Record 20 of Set 7 | anabar
# City not found. Skipping...
# Processing Record 21 of Set 7 | mont-dore
# Processing Record 22 of Set 7 | codrington
# Processing Record 23 of Set 7 | port alfred
# Processing Record 24 of Set 7 | koton-karfe
# Processing Record 25 of Set 7 | rosarito
# Processing Record 26 of Set 7 | mufulira
# Processing Record 27 of Set 7 | lichinga
# Processing Record 28 of Set 7 | betong
# Processing Record 29 of Set 7 | afaahiti
# Processing Record 30 of Set 7 | abadeh
# Processing Record 31 of Set 7 | yarmouth
# Processing Record 32 of Set 7 | vengerovo
# Processing Record 33 of Set 7 | mata-utu
# Processing Record 34 of Set 7 | kievka
# Processing Record 35 of Set 7 | harper
# Processing Record 36 of Set 7 
# Processing Record 3 of Set 9 | coquimbo
# Processing Record 4 of Set 9 | calama
# Processing Record 5 of Set 9 | balsas
# Processing Record 6 of Set 9 | kotka
# Processing Record 7 of Set 9 | gaiman
# Processing Record 8 of Set 9 | motueka
# Processing Record 9 of Set 9 | machilipatnam
# Processing Record 10 of Set 9 | port shepstone
# Processing Record 11 of Set 9 | brookings
# Processing Record 12 of Set 9 | paita
# Processing Record 13 of Set 9 | waingapu
# Processing Record 14 of Set 9 | luza
# Processing Record 15 of Set 9 | utrik
# Processing Record 16 of Set 9 | sai buri
# Processing Record 17 of Set 9 | namibe
# Processing Record 18 of Set 9 | hirson
# Processing Record 19 of Set 9 | tsiombe
# Processing Record 20 of Set 9 | tindouf
# Processing Record 21 of Set 9 | otjimbingwe
# Processing Record 22 of Set 9 | marsa alam
# Processing Record 23 of Set 9 | sirte
# Processing Record 24 of Set 9 | cam ranh
# Processing Record 25 of Set 9 | fort st. john
# Processing Record 26 of Set 9 | novoagansk
# Processing Record 27 of Set 9 | chavusy
# Processing Record 28 of Set 9 | fort william
# Processing Record 29 of Set 9 | wynyard
# Processing Record 30 of Set 9 | valparaiso
# Processing Record 31 of Set 9 | huron
# Processing Record 32 of Set 9 | villa gesell
# Processing Record 33 of Set 9 | salt spring island
# Processing Record 34 of Set 9 | taltal
# Processing Record 35 of Set 9 | horta
# Processing Record 36 of Set 9 | lorengau
# Processing Record 37 of Set 9 | aykhal
# Processing Record 38 of Set 9 | nova sintra
# Processing Record 39 of Set 9 | auki
# Processing Record 40 of Set 9 | cidreira
# Processing Record 41 of Set 9 | ancud
# Processing Record 42 of Set 9 | ylivieska
# Processing Record 43 of Set 9 | lodwar
# Processing Record 44 of Set 9 | portland
# Processing Record 45 of Set 9 | ierapetra
# Processing Record 46 of Set 9 | korsakov
# Processing Record 47 of Set 9 | fada n'gourma
# Processing Record 48 of Set 9 | pibor
# City not found. Skipping...
# Processing Record 49 of Set 9 | tual
# Processing Record 0 of Set 10 | livadeia
# Processing Record 1 of Set 10 | faya-largeau
# Processing Record 2 of Set 10 | messini
# Processing Record 3 of Set 10 | rucava
# Processing Record 4 of Set 10 | visby
# Processing Record 5 of Set 10 | puerto armuelles
# Processing Record 6 of Set 10 | rovaniemi
# Processing Record 7 of Set 10 | aral
# Processing Record 8 of Set 10 | milton
# Processing Record 9 of Set 10 | mossel bay
# Processing Record 10 of Set 10 | palikir - national government center
# Processing Record 11 of Set 10 | kuching
# Processing Record 12 of Set 10 | howrah
# Processing Record 13 of Set 10 | batesburg-leesville
# Processing Record 14 of Set 10 | preobrazheniye
# Processing Record 15 of Set 10 | serra branca
# Processing Record 16 of Set 10 | geneina
# Processing Record 17 of Set 10 | talcahuano
# Processing Record 18 of Set 10 | hasaki
# Processing Record 19 of Set 10 | golyshmanovo
# Processing Record 20 of Set 10 | bannu
# Processing Record 21 of Set 10 | merizo village
# Processing Record 22 of Set 10 | nukunonu
# City not found. Skipping...
# Processing Record 23 of Set 10 | greystones
# Processing Record 24 of Set 10 | luwuk
# Processing Record 25 of Set 10 | shingu
# Processing Record 26 of Set 10 | kuanda
# Processing Record 27 of Set 10 | altai
# Processing Record 28 of Set 10 | isiro
# Processing Record 29 of Set 10 | kralendijk
# Processing Record 30 of Set 10 | chegdomyn
# Processing Record 31 of Set 10 | sumbe
# Processing Record 32 of Set 10 | zliten
# Processing Record 33 of Set 10 | sandnessjoen
# Processing Record 34 of Set 10 | novyy rogachik
# Processing Record 35 of Set 10 | al bawiti
# Processing Record 36 of Set 10 | rio grande
# Processing Record 37 of Set 10 | crookston
# Processing Record 38 of Set 10 | kondopoga
# Processing Record 39 of Set 10 | ankazoabo
# Processing Record 40 of Set 10 | ha tinh
# Processing Record 41 of Set 10 | warrnambool
# Processing Record 42 of Set 10 | kailua-kona
# Processing Record 43 of Set 10 | taiobeiras
# Processing Record 44 of Set 10 | mana
# Processing Record 45 of Set 10 | bologoye-4
# City not found. Skipping...
# Processing Record 46 of Set 10 | strelka
# Processing Record 47 of Set 10 | badger
# Processing Record 48 of Set 10 | flin flon
# Processing Record 49 of Set 10 | los llanos de aridane
# Processing Record 0 of Set 11 | ghat
# Processing Record 1 of Set 11 | nuuk
# Processing Record 2 of Set 11 | yanbu
# Processing Record 3 of Set 11 | fatehpur
# Processing Record 4 of Set 11 | pajok
# Processing Record 5 of Set 11 | sambava
# Processing Record 6 of Set 11 | dhuusamarreeb
# Processing Record 7 of Set 11 | kapa'a
# Processing Record 8 of Set 11 | cascais
# Processing Record 9 of Set 11 | tabas
# Processing Record 10 of Set 11 | malazgirt
# Processing Record 11 of Set 11 | opuwo
# Processing Record 12 of Set 11 | arrifes
# Processing Record 13 of Set 11 | farah
# Processing Record 14 of Set 11 | susanville
# Processing Record 15 of Set 11 | timimoun
# Processing Record 16 of Set 11 | borgarnes
# Processing Record 17 of Set 11 | vilhena
# Processing Record 18 of Set 11 | tobi village
# City not found. Skipping...
# Processing Record 19 of Set 11 | marshalltown
# Processing Record 20 of Set 11 | kristiansund
# Processing Record 21 of Set 11 | piacabucu
# Processing Record 22 of Set 11 | tamandare
# Processing Record 23 of Set 11 | glace bay
# Processing Record 24 of Set 11 | jiutai
# Processing Record 25 of Set 11 | qui nhon
# Processing Record 26 of Set 11 | flagstaff
# Processing Record 27 of Set 11 | ghadamis
# Processing Record 28 of Set 11 | toppenish
# Processing Record 29 of Set 11 | hayma'
# City not found. Skipping...
# Processing Record 30 of Set 11 | ben gardane
# Processing Record 31 of Set 11 | laurentides
# Processing Record 32 of Set 11 | carutapera
# Processing Record 33 of Set 11 | peace river
# Processing Record 34 of Set 11 | igarka
# Processing Record 35 of Set 11 | gargalianoi
# Processing Record 36 of Set 11 | tranovaho
# City not found. Skipping...
# Processing Record 37 of Set 11 | malabar
# Processing Record 38 of Set 11 | veraval
# Processing Record 39 of Set 11 | barrancas
# Processing Record 40 of Set 11 | pasni
# Processing Record 41 of Set 11 | pinotepa nacional
# Processing Record 42 of Set 11 | wenceslau braz
# Processing Record 43 of Set 11 | labytnangi
# Processing Record 44 of Set 11 | umatac village
# City not found. Skipping...
# Processing Record 45 of Set 11 | pangoa
# Processing Record 46 of Set 11 | dadonghai
# City not found. Skipping...
# Processing Record 47 of Set 11 | sho'rchi
# Processing Record 48 of Set 11 | ola
# Processing Record 49 of Set 11 | champasak
# Processing Record 0 of Set 12 | gisborne
# Processing Record 1 of Set 12 | urucui
# Processing Record 2 of Set 12 | corfu
# Processing Record 3 of Set 12 | ocean pointe
# City not found. Skipping...
# Processing Record 4 of Set 12 | florence
# Processing Record 5 of Set 12 | newman
# Processing Record 6 of Set 12 | baki
# Processing Record 7 of Set 12 | hobyo
# Processing Record 8 of Set 12 | plettenberg bay
# Processing Record 9 of Set 12 | caorle
# Processing Record 10 of Set 12 | yelizovo
# Processing Record 11 of Set 12 | yung shue wan
# Processing Record 12 of Set 12 | port blair
# Processing Record 13 of Set 12 | mutuali
# Processing Record 14 of Set 12 | alaghsas
# Processing Record 15 of Set 12 | lauro de freitas
# Processing Record 16 of Set 12 | pangai
# Processing Record 17 of Set 12 | kano
# Processing Record 18 of Set 12 | serta
# Processing Record 19 of Set 12 | ikovka
# Processing Record 20 of Set 12 | dazhou
# Processing Record 21 of Set 12 | phalauda
# Processing Record 22 of Set 12 | seguela
# Processing Record 23 of Set 12 | rezekne
# Processing Record 24 of Set 12 | toliara
# Processing Record 25 of Set 12 | soroca
# Processing Record 26 of Set 12 | greenwood
# Processing Record 27 of Set 12 | puerto baquerizo moreno
# Processing Record 28 of Set 12 | tengrela
# Processing Record 29 of Set 12 | margate
# Processing Record 30 of Set 12 | laikit, laikit ii (dimembe)
# Processing Record 31 of Set 12 | luang prabang
# Processing Record 32 of Set 12 | buta
# Processing Record 33 of Set 12 | shetpe
# Processing Record 34 of Set 12 | cockburn town
# Processing Record 35 of Set 12 | halaucesti
# Processing Record 36 of Set 12 | san jose del guaviare
# Processing Record 37 of Set 12 | galesong
# Processing Record 38 of Set 12 | santiago de cao
# Processing Record 39 of Set 12 | mendoza
# Processing Record 40 of Set 12 | athens
# Processing Record 41 of Set 12 | lata
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          563
# Lat           563
# Lng           563
# Max Temp      563
# Humidity      563
# Cloudiness    563
# Wind Speed    563
# Country       563
# Date          563
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         grytviken -54.2811  -36.5092     32.41        88          42
# 1           ushuaia -54.8000  -68.3000     44.26        70          75
# 2  kuala terengganu   5.3302  103.1408     85.95        79          20
# 3     port mathurin -19.6833   63.4167     76.66        81           2
# 4  nizhnesortymskiy  62.4397   71.7603     50.45        88          98
#
#    Wind Speed Country        Date
# 0        9.10      GS  1697532205
# 1       13.80      AR  1697532080
# 2        7.00      MY  1697532309
# 3       11.99      MU  1697532310
# 4       11.12      RU  1697532311

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               grytviken -54.2811  -36.5092     32.41        88          42
# 1                 ushuaia -54.8000  -68.3000     44.26        70          75
# 2        kuala terengganu   5.3302  103.1408     85.95        79          20
# 3           port mathurin -19.6833   63.4167     76.66        81           2
# 4        nizhnesortymskiy  62.4397   71.7603     50.45        88          98
#
#          Wind Speed Country        Date
# City_ID
# 0              9.10      GS  1697532205
# 1             13.80      AR  1697532080
# 2              7.00      MY  1697532309
# 3             11.99      MU  1697532310
# 4             11.12      RU  1697532311

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"],city_data_df["Max Temp"],facecolor = "steelblue", edgecolor = "black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs Temperature (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(C)")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"],city_data_df["Humidity"],facecolor = "steelblue", edgecolor = "black")

# Incorporate the other graph properties
plt.title("City Latitude vs Humidity (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"],city_data_df["Cloudiness"],facecolor = "steelblue", edgecolor = "black")

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"],city_data_df["Wind Speed"],facecolor = "steelblue", edgecolor = "black")

# Incorporate the other graph properties
plt.title("City Latitude vs Wind Speed (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(m/s)")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression(x,y):
    correlation = st.pearsonr(x,y) 
    print(f"The r-squared is : {round(correlation[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"]>0]

# Display sample data
northern_hemi_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2        kuala terengganu   5.3302  103.1408     85.95        79          20
# 4        nizhnesortymskiy  62.4397   71.7603     50.45        88          98
# 7            longyearbyen  78.2186   15.6401     24.64        63          75
# 9                enewetak  11.3474  162.3373     84.34        76           3
# 10          prince rupert  54.3161 -130.3201     53.69        92         100
#
#          Wind Speed Country        Date
# City_ID
# 2              7.00      MY  1697532309
# 4             11.12      RU  1697532311
# 7             11.50      SJ  1697532315
# 9             14.61      MH  1697532317
# 10            24.16      CA  1697532213

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"]<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                         City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 0                  grytviken -54.2811 -36.5092     32.41        88
# 1                    ushuaia -54.8000 -68.3000     44.26        70
# 3              port mathurin -19.6833  63.4167     76.66        81
# 5                salinopolis  -0.6136 -47.3561     78.39        86
# 6        san antonio de pale  -1.4014   5.6325     78.33        80
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                42        9.10      GS  1697532205
# 1                75       13.80      AR  1697532080
# 3                 2       11.99      MU  1697532310
# 5                66        8.99      BR  1697532312
# 6               100        5.88      GQ  1697532314

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
equation = linear_regression(northern_hemi_df["Lat"],northern_hemi_df["Max Temp"])

#Annotate the plot
annotate(equation, 20,20)

# Set a title
plt.title("Northen Hemisphere - Temperature vs. Latitude Linear Regression Plot")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

plt.tight_layout()

plt.show()
# Save the figure
plt.savefig("output_data/Northen Hemisphere - Temperature vs. Latitude Linear Regression Plot.png")
# Out:
# The r-squared is : -0.86

# %%
# Linear regression on Southern Hemisphere
equation = linear_regression(southern_hemi_df["Lat"],southern_hemi_df["Max Temp"])

#Annotate the plot
annotate(equation, -30,40)

# Set a title
plt.title("Southern Hemisphere - Temperature vs. Latitude Linear Regression Plot")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

plt.tight_layout()

plt.show()
# Save the figure
plt.savefig("output_data/Southern Hemisphere - Temperature vs. Latitude Linear Regression Plot.png")
# Out:
# The r-squared is : 0.77

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Strong negative correlation(-0.87) between latitude and Max Temperature for Northern Hemisphere
# Moderate possitive correlation(0.77) between latitude and Max Temperature for Southern Hemisphere

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
equation = linear_regression(northern_hemi_df["Lat"],northern_hemi_df["Humidity"])

#Annotate the plot
annotate(equation, 50,20)

# Set a title
plt.title("Northen Hemisphere - Humidity vs. Latitude Linear Regression Plot")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

plt.tight_layout()

plt.show()
# Save the figure
plt.savefig("output_data/Northen Hemisphere - Humidity vs. Latitude Linear Regression Plot.png")
# Out:
# The r-squared is : 0.15

# %%
# Southern Hemisphere
equation = linear_regression(southern_hemi_df["Lat"],southern_hemi_df["Humidity"])

#Annotate the plot
annotate(equation, -30,40)

# Set a title
plt.title("Southern Hemisphere - Humidity vs. Latitude Linear Regression Plot")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

plt.tight_layout()

plt.show()
# Save the figure
plt.savefig("output_data/Southern Hemisphere - Humidity vs. Latitude Linear Regression Plot.png")
# Out:
# The r-squared is : -0.03

# %% [markdown]
# **Discussion about the linear relationship:**
# There is a moderate possitive correlation( 0.08) between Latitude and Humidity for Northern Hemisphere
#
# There is a strong negative correlation(-0.02) between Latitude and Humidity for Southern Hemisphere

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
equation = linear_regression(northern_hemi_df["Lat"],northern_hemi_df["Cloudiness"])

#Annotate the plot
annotate(equation, 50,20)

# Set a title
plt.title("Northen Hemisphere - Cloudiness vs. Latitude Linear Regression Plot")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

plt.tight_layout()

plt.show()
# Save the figure
plt.savefig("output_data/Northen Hemisphere - Cloudiness vs. Latitude Linear Regression Plot.png")
# Out:
# The r-squared is : 0.16

# %%
# Southern Hemisphere
equation = linear_regression(southern_hemi_df["Lat"],southern_hemi_df["Cloudiness"])

#Annotate the plot
annotate(equation, -30,40)

# Set a title
plt.title("Southern Hemisphere - Cloudiness vs. Latitude Linear Regression Plot")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

plt.tight_layout()

plt.show()
# Save the figure
plt.savefig("output_data/Southern Hemisphere - Cloudiness vs. Latitude Linear Regression Plot.png")
# Out:
# The r-squared is : 0.16

# %% [markdown]
# **Discussion about the linear relationship:**
# Strong possitive corrleation(0.14) between Latitude and Cloudiness for Northern Hemisphere.
#
# Moderate possitive correlation(0.06) between Latitude and Cloudiness for Southern Hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
equation = linear_regression(northern_hemi_df["Lat"],northern_hemi_df["Wind Speed"])

#Annotate the plot
annotate(equation, 50,20)

# Set a title
plt.title("Northen Hemisphere - Wind Speed vs. Latitude Linear Regression Plot")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (m/s)")

plt.tight_layout()

plt.show()
# Save the figure
plt.savefig("output_data/Northen Hemisphere - Wind Speed vs. Latitude Linear Regression Plot.png")
# Out:
# The r-squared is : 0.18

# %%
# Southern Hemisphere
equation = linear_regression(southern_hemi_df["Lat"],southern_hemi_df["Wind Speed"])

#Annotate the plot
annotate(equation, -50,8)

# Set a title
plt.title("Southern Hemisphere - Wind Speed vs. Latitude Linear Regression Plot")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (m/s)")

plt.tight_layout()

plt.show()
# Save the figure
plt.savefig("output_data/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression Plot.png")
# Out:
# The r-squared is : -0.04

# %% [markdown]
# **Discussion about the linear relationship:**
#
# strong Posstive correlation(0.022) between Latitude and Wind Speed for Northern Hemisphere
#
# Weak negative correlation(-0.33) between Latitude and Wind Speed for Southern Hemisphere
